# %%
import pandas as pd

# %%
str_ ="PBT.txt"

# %%
with open(str_, 'r') as f:
    txt = f.read()
for char in txt:
    if char == '\n':
        print()
    else:
        print(char, end='')
# Out:
# Datum	11.05.12
# Probenkennz.	PBT weiÂ§
# Geschwindigkeit	20	mm/min
# Kraftmaximum	2359,41	N
# ProbenhÅ¡he a0	3,95	mm
# Probenbreite b0	10,4	mm
# LÅ nge l0	70	mm
# ProbenhÅ¡he aU NACH ZUGVERSUCH	3,27	mm
# Probenbreite bU NACH ZUGVERSUCH	8,55	mm
# LÅ nge lU NACH ZUGVERSUCH	76,4	mm
# Standardweg	Standardkraft
# mm	N
# 0,00603522	4,71302
# 0,0217462	12,4582
# 0,0339658	16,0836
# 0,0467987	19,1158
# 0,0598204	22,1809
# 0,0729836	25,3778
# 0,0862884	29,1021
# 0,099546	33,2548
# 0,112898	37,2428
# 0,126297	41,0659
# 0,139602	45,1198
# 0,152907	49,5362
# 0,166258	53,9196
# 0,17961	58,2701
# 0,192915	62,8843
# 0,20622	67,9269
# 0,219572	73,0024
# 0,232924	78,078
# 0,246323	83,582
# 0,259581	89,4816
# 0,272932	95,3481
# 0,28619	101,314
# 0,299542	107,444
# 0,312941	113,574
# 0,326293	119,836
# 0,339598	126,098
# 0,352903	132,459
# 0,366207	138,787
# 0,379559	145,214
# 0,392911	151,838
# 0,406263	158,496
# 0,419568	165,252
# 0,43292	172,042
# 0,446272	178,93
# 0,459577	185,72
# ...

# %%
type(txt)
# Out:
# str

# %%
df = pd.read_csv(str_, sep="\t", header=[10,11])

# %%
df
# Out:
#      Standardweg Standardkraft Unnamed: 2_level_0
#               mm             N Unnamed: 2_level_1
# 0     0,00603522       4,71302                NaN
# 1      0,0217462       12,4582                NaN
# 2      0,0339658       16,0836                NaN
# 3      0,0467987       19,1158                NaN
# 4      0,0598204       22,1809                NaN
# ...          ...           ...                ...
# 1068     14,5463          1983                NaN
# 1069     14,5596        1968,2                NaN
# 1070     14,5729       1951,09                NaN
# 1071     14,5863       1930,99                NaN
# 1072     14,5996        1906,7                NaN
#
# [1073 rows x 3 columns]

# %%
df.to_excel(f"{str_[:-3]}xlsx")
str_[:-3]
# Out:
# 'PBT.'
